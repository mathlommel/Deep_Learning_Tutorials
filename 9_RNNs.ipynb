# %% [markdown]
# [![Open In SageMaker Studio Lab](https://studiolab.sagemaker.aws/studiolab.svg)](https://studiolab.sagemaker.aws/import/github/dkaratzas/DL2022-23/blob/main/Problems%208%20-%20RNNs/P8_RNNs.ipynb)

# %% [markdown]
# # Text generation with an RNN
#
# In this notebook we will learn how to generate text with a Recurrent Neural Network.
#
# We will work with a dataset of Shakespeare's writing from Andrej Karpathy's article [The Unreasonable Effectiveness of Recurrent Neural Networks](http://karpathy.github.io/2015/05/21/rnn-effectiveness/).
#
# Given a sequence of characters from this data (for example "Shakespear"), we will train a model to predict the next character in the sequence ("e"). Longer sequences of text can be generated by calling the model repeatedly.

# %% [markdown]
# ### Import the necessary modules

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
from torch.utils.data import TensorDataset, DataLoader, Dataset

import matplotlib.pyplot as plt
from collections import Counter
import time
import os
import copy
print("PyTorch Version: ",torch.__version__)
# Out:
# PyTorch Version:  2.2.1+cu121

# %%
#If this cell fails you need to change the runtime of your colab notebook to GPU
# Go to Runtime -> Change Runtime Type and select GPU
assert torch.cuda.is_available(), "GPU is not enabled"

#  use gpu if available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)
# Out:
# Using device: cuda

# %% [markdown]
# ### Download the Shakespeare dataset

# %%
! wget https://storage.googleapis.com/download.tensorflow.org/data/shakespeare.txt
# Out:
# --2024-04-24 00:54:22--  https://storage.googleapis.com/download.tensorflow.org/data/shakespeare.txt
# Resolving storage.googleapis.com (storage.googleapis.com)... 74.125.137.207, 142.251.2.207, 2607:f8b0:4023:c06::cf, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|74.125.137.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1115394 (1.1M) [text/plain]
# Saving to: ‘shakespeare.txt.1’
#
# shakespeare.txt.1   100%[===================>]   1.06M  --.-KB/s    in 0.006s
#
# 2024-04-24 00:54:22 (177 MB/s) - ‘shakespeare.txt.1’ saved [1115394/1115394]

# %% [markdown]
# ###  Create a dataset class
#
# For training we need a dataset of (input, label) pairs. Where input and label are sequences of characters. At each time step the input is the current character and the label is the next character. For example:
#
# ```
# input = ['S', 'h', 'a', 'k', 'e', 's', 'p', 'e', 'a', 'r']
# label = ['h', 'a', 'k', 'e', 's', 'p', 'e', 'a', 'r', 'e']
#  ```
#
# Actually we will vectorize the characters to convert them into numerical values.
#
# ```
# input = [44, 7, 0, 10, 4, 18, 15, 4, 0, 17]
# label = [7, 0, 10, 4, 18, 15, 4, 0, 17, 4]
# ```
#
# where each integer value is a class label, and the number of classes is the number of unique characters in our training data (our vocabulary size).

# %%
Dataset?

# %%
class DatasetFromTextFile(Dataset):
    def __init__(self, filename, sequence_length):
        self.filename = filename
        self.sequence_length = sequence_length

        # The whole sequence of characters in the text file (including characters like the end of line character '\n', punctuation marks, etc.)
        self.chars = self.load_chars()
        # The list of unique characters (our vocabulary)
        self.uniq_chars = self.get_uniq_chars()

        # A dictionary with indices as keys and characters as values
        self.index_to_char = {index: char for index, char in enumerate(self.uniq_chars)}
        # A dictionary with characters as keys and indices as values
        self.char_to_index = {char: index for index, char in enumerate(self.uniq_chars)}

        # The whole sequence of character indexes
        # We want to vectorize our text using one-hot vectors at character level
        # But instead of using the one-hot vector we just keep the index of the 1 value
        self.chars_indices = [self.char_to_index[w] for w in self.chars]

        # Split the sequence into chunks of `sequence_length` characters
        # `x` is the input to the model and `y` is the output of the model
        # `y` is the same seuqence as `x` but one character shifted to the right.
        self.x, self.y = self.get_data()

    def load_chars(self):
        with open(self.filename) as fp:
            text = fp.read()
        print(f'Length of text: {len(text)} characters')
        return text

    def get_uniq_chars(self):
        char_counts = Counter(self.chars)
        uniq_chars = sorted(char_counts, key=char_counts.get, reverse=True)
        print(f'Unique characters (vocabulary size): {len(uniq_chars)}')
        return uniq_chars

    def get_data(self):
        x,y = [], []
        for index in range(0, len(self.chars_indices)-self.sequence_length, self.sequence_length):
            x.append(np.array(self.chars_indices[index:index+self.sequence_length]))
            y.append(np.array(self.chars_indices[index+1:index+self.sequence_length+1]))

        return  torch.from_numpy(np.array(x)), torch.from_numpy(np.array(y)).long()

    def __len__(self):
        return len(self.y)

    def __getitem__(self, idx):
        assert ((idx >= 0) & (idx < len(self.y))), "Dataset index out of range"
        return self.x[idx], self.y[idx]

# %% [markdown]
# Now we can use [`torch.utils.data.Dataloader`](https://pytorch.org/docs/stable/data.html) class to create the PyTorch dataloader.

# %%
# Create the dataset
sequence_length = 100
ShakespeareDataset = DatasetFromTextFile('shakespeare.txt', sequence_length)

print(f'We have {ShakespeareDataset.x.shape[0]} input sequence samples of length {ShakespeareDataset.x.shape[1]} \
and {ShakespeareDataset.y.shape[0]} label sequences of length {ShakespeareDataset.y.shape[1]}')

# Create the Torch DataLoader
batch_size = 64
train_loader = DataLoader(ShakespeareDataset, shuffle=True, batch_size=batch_size, drop_last=True)
# Out:
# Length of text: 1115394 characters
# Unique characters (vocabulary size): 65
# We have 11153 input sequence samples of length 100 and 11153 label sequences of length 100

# %% [markdown]
# ## Build the model
#
# Our model has three layers:
#
# * `torch.nn.Embedding`: The input layer. A trainable lookup table that will map each character-ID (class ID) to a dense vector with `embedding_dim` dimensions;
# * `torch.nn.GRU`: A type of RNN with `hidden_dim` units
# * `torch.nn.Linear`: The output layer, with number of outputs as our vocabulary size (`len(dataset.uniq_chars)`). It outputs one logit for each character in the vocabulary. These are the log-likelihood of each character according to the model.

# %% [markdown]
# For each character the model looks up the embedding, runs the GRU one timestep with the embedding as input, and applies the dense layer to generate logits predicting the log-likelihood of the next character:
#
# ![text_generation_training.png](data:image/png;base64,...)
#
# Image source: http://www.tensorflow.org

# %% [markdown]
# <span style="color:blue">
#
# **Exercise 1:** Complete the code of the `Model` class. You need to embed your input using an `nn.Embedding` layer, create a GRU with `n_layers`, and then compute the output logits.
#
# </span>

# %%
class Model(nn.Module):
    def __init__(self, input_dim, embedding_dim, hidden_dim, output_dim, n_layers, drop_prob=0.):
        super(Model, self).__init__()
        self.hidden_dim = hidden_dim
        self.n_layers = n_layers

        # YOUR CODE HERE
        self.embedding = torch.nn.Embedding(num_embeddings = input_dim, embedding_dim = embedding_dim)
        self.gru = torch.nn.GRU(input_size = embedding_dim, hidden_size = hidden_dim, num_layers = n_layers, batch_first=True, bidirectional = False)
        self.fc = torch.nn.Linear(in_features = hidden_dim, out_features = output_dim)


    def forward(self, x, h):
        emb = self.embedding(x)
        out, h = self.gru(emb, h)
        out = self.fc(out)
        return out, h

    def init_hidden(self, batch_size):
        " Initialize the hidden state of the RNN to zeros"
        hidden = nn.Parameter(torch.zeros(self.n_layers, batch_size, self.hidden_dim))
        return hidden

# %% [markdown]
# Now we can instantiate the model as follows:

# %%
input_dim = len(ShakespeareDataset.uniq_chars)
embedding_dim = 300
hidden_dim = 1024
output_dim = len(ShakespeareDataset.uniq_chars)
n_layers = 2
drop_prob = 0.2

model = Model(input_dim, embedding_dim, hidden_dim, output_dim, n_layers, drop_prob).to(device)

print(model)
# Out:
# Model(
#   (embedding): Embedding(65, 300)
#   (gru): GRU(300, 1024, num_layers=2, batch_first=True)
#   (fc): Linear(in_features=1024, out_features=65, bias=True)
# )

# %% [markdown]
# ## Quick Experiment

# %% [markdown]
# Let's create a string and pass it through our model

# %%
data = torch.tensor([ShakespeareDataset.char_to_index[w] for w in "Hello"])
print(data.shape)
# Out:
# torch.Size([5])

# %% [markdown]
# Our model expects a batch. We will create a batch of 1, using this one data point we have created

# %%
data = data.unsqueeze(0) # this adds one more dimension (the batch one) to our data
print(data.shape)
# Out:
# torch.Size([1, 5])

# %% [markdown]
# Time to pass this through our model. To do so, we need to (1) move our data to the same device like the model and (2) initialise the state of our RNN

# %%
data = data.to(device)
state = model.init_hidden(batch_size = 1) # remember that we will use just a single data point jere
state = state.to(device)
out, state = model(data, state) # The forward pass expects the current state as an argument, and returns the updated state in the output

print(out.shape)
# Out:
# torch.Size([1, 5, 65])

# %% [markdown]
# Our output returns 65 probability values for each character... We need to find which one is the maximum probability for each position, and convert it to the corresponding character

# %%
_, idxs = torch.max(out[0], dim = 1)

print([ShakespeareDataset.index_to_char[int(c)] for c in idxs])
# Out:
# ['N', '-', 'D', 'D', 'D']

# %% [markdown]
# As expected both inputs and outputs have the same shape, and the predicted characters are just random since the model is not trained yet.

# %% [markdown]
# ## Train the model
#
# Training a language model is essentially a classification problem. Given the previous RNN state, and the input character at this time step, predict the class of the next character.
#
# <span style="color:blue">
#
# **Exercise 2:** which loss function do you think we shall use to train our model?
#
# $\to$ The cross entropy loss (since we are doing a multi-class classification, with Softmax)
#
# </span>

# %%
def train(dataloader, model, batch_size, sequence_length, num_epochs):
    model.train()

    criterion =  nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=0.001)

    losses = []
    for epoch in range(num_epochs):

        for batch, (x, y) in enumerate(dataloader):
            state = model.init_hidden(batch_size) # Start with a new state in each batch
            state = state.to(device)

            x = x.to(device)
            y = y.to(device)
            optimizer.zero_grad()

            y_pred, state = model(x, state)
            loss = criterion(y_pred.transpose(1, 2), y)

            loss.backward()
            optimizer.step()

            if batch%30 == 0:
                print({ 'epoch': epoch, 'batch': batch, 'loss': loss.item() })
                losses.append(loss.item())
    return losses

# %% [markdown]
# Now train the model for 20 epochs and visualize the training loss curve.

# %%
num_epochs = 20

losses = train(train_loader, model, batch_size, sequence_length, num_epochs)
# Out:
# {'epoch': 0, 'batch': 0, 'loss': 4.177779674530029}
# {'epoch': 0, 'batch': 30, 'loss': 2.219489812850952}
# {'epoch': 0, 'batch': 60, 'loss': 1.954404592514038}
# {'epoch': 0, 'batch': 90, 'loss': 1.7880576848983765}
# {'epoch': 0, 'batch': 120, 'loss': 1.6521594524383545}
# {'epoch': 0, 'batch': 150, 'loss': 1.603381633758545}
# {'epoch': 1, 'batch': 0, 'loss': 1.537624716758728}
# {'epoch': 1, 'batch': 30, 'loss': 1.4642375707626343}
# {'epoch': 1, 'batch': 60, 'loss': 1.470499873161316}
# {'epoch': 1, 'batch': 90, 'loss': 1.4302377700805664}
# {'epoch': 1, 'batch': 120, 'loss': 1.4198721647262573}
# {'epoch': 1, 'batch': 150, 'loss': 1.4263243675231934}
# {'epoch': 2, 'batch': 0, 'loss': 1.3456048965454102}
# {'epoch': 2, 'batch': 30, 'loss': 1.3373030424118042}
# {'epoch': 2, 'batch': 60, 'loss': 1.359804630279541}
# {'epoch': 2, 'batch': 90, 'loss': 1.3419761657714844}
# {'epoch': 2, 'batch': 120, 'loss': 1.3588656187057495}
# {'epoch': 2, 'batch': 150, 'loss': 1.3006503582000732}
# {'epoch': 3, 'batch': 0, 'loss': 1.2595924139022827}
# {'epoch': 3, 'batch': 30, 'loss': 1.307204008102417}
# {'epoch': 3, 'batch': 60, 'loss': 1.274467945098877}
# {'epoch': 3, 'batch': 90, 'loss': 1.245941162109375}
# {'epoch': 3, 'batch': 120, 'loss': 1.3147881031036377}
# {'epoch': 3, 'batch': 150, 'loss': 1.2834429740905762}
# {'epoch': 4, 'batch': 0, 'loss': 1.2053306102752686}
# {'epoch': 4, 'batch': 30, 'loss': 1.1992697715759277}
# {'epoch': 4, 'batch': 60, 'loss': 1.2142208814620972}
# {'epoch': 4, 'batch': 90, 'loss': 1.2228139638900757}
# {'epoch': 4, 'batch': 120, 'loss': 1.2636351585388184}
# {'epoch': 4, 'batch': 150, 'loss': 1.2013227939605713}
# {'epoch': 5, 'batch': 0, 'loss': 1.1445451974868774}
# {'epoch': 5, 'batch': 30, 'loss': 1.1587108373641968}
# {'epoch': 5, 'batch': 60, 'loss': 1.1891891956329346}
# {'epoch': 5, 'batch': 90, 'loss': 1.2005698680877686}
# {'epoch': 5, 'batch': 120, 'loss': 1.138818621635437}
# {'epoch': 5, 'batch': 150, 'loss': 1.1726055145263672}
# {'epoch': 6, 'batch': 0, 'loss': 1.1069929599761963}
# {'epoch': 6, 'batch': 30, 'loss': 1.110295295715332}
# {'epoch': 6, 'batch': 60, 'loss': 1.1113790273666382}
# {'epoch': 6, 'batch': 90, 'loss': 1.1471946239471436}
# {'epoch': 6, 'batch': 120, 'loss': 1.134477972984314}
# {'epoch': 6, 'batch': 150, 'loss': 1.1622557640075684}
# {'epoch': 7, 'batch': 0, 'loss': 1.06339693069458}
# {'epoch': 7, 'batch': 30, 'loss': 1.084816813468933}
# {'epoch': 7, 'batch': 60, 'loss': 1.090914249420166}
# {'epoch': 7, 'batch': 90, 'loss': 1.067487359046936}
# {'epoch': 7, 'batch': 120, 'loss': 1.0857220888137817}
# {'epoch': 7, 'batch': 150, 'loss': 1.1142418384552002}
# {'epoch': 8, 'batch': 0, 'loss': 0.9793667793273926}
# {'epoch': 8, 'batch': 30, 'loss': 1.0230094194412231}
# {'epoch': 8, 'batch': 60, 'loss': 1.0215911865234375}
# {'epoch': 8, 'batch': 90, 'loss': 1.025770902633667}
# {'epoch': 8, 'batch': 120, 'loss': 1.0556801557540894}
# {'epoch': 8, 'batch': 150, 'loss': 1.0534881353378296}
# {'epoch': 9, 'batch': 0, 'loss': 0.9284987449645996}
# {'epoch': 9, 'batch': 30, 'loss': 0.9445773959159851}
# {'epoch': 9, 'batch': 60, 'loss': 0.9325977563858032}
# {'epoch': 9, 'batch': 90, 'loss': 0.9858060479164124}
# {'epoch': 9, 'batch': 120, 'loss': 0.9771632552146912}
# {'epoch': 9, 'batch': 150, 'loss': 0.9998951554298401}
# {'epoch': 10, 'batch': 0, 'loss': 0.8906691670417786}
# {'epoch': 10, 'batch': 30, 'loss': 0.8784914612770081}
# {'epoch': 10, 'batch': 60, 'loss': 0.9151294827461243}
# {'epoch': 10, 'batch': 90, 'loss': 0.9163204431533813}
# {'epoch': 10, 'batch': 120, 'loss': 0.941348671913147}
# {'epoch': 10, 'batch': 150, 'loss': 0.9607612490653992}
# {'epoch': 11, 'batch': 0, 'loss': 0.8208338022232056}
# {'epoch': 11, 'batch': 30, 'loss': 0.833294689655304}
# {'epoch': 11, 'batch': 60, 'loss': 0.8488386273384094}
# {'epoch': 11, 'batch': 90, 'loss': 0.8610365986824036}
# {'epoch': 11, 'batch': 120, 'loss': 0.8843079209327698}
# {'epoch': 11, 'batch': 150, 'loss': 0.8857866525650024}
# {'epoch': 12, 'batch': 0, 'loss': 0.7696465253829956}
# {'epoch': 12, 'batch': 30, 'loss': 0.768044650554657}
# {'epoch': 12, 'batch': 60, 'loss': 0.7842134237289429}
# {'epoch': 12, 'batch': 90, 'loss': 0.8096565008163452}
# {'epoch': 12, 'batch': 120, 'loss': 0.8344053030014038}
# {'epoch': 12, 'batch': 150, 'loss': 0.8479529023170471}
# {'epoch': 13, 'batch': 0, 'loss': 0.7150914072990417}
# {'epoch': 13, 'batch': 30, 'loss': 0.6984372735023499}
# {'epoch': 13, 'batch': 60, 'loss': 0.715299665927887}
# {'epoch': 13, 'batch': 90, 'loss': 0.7497575879096985}
# {'epoch': 13, 'batch': 120, 'loss': 0.7950961589813232}
# {'epoch': 13, 'batch': 150, 'loss': 0.784400999546051}
# {'epoch': 14, 'batch': 0, 'loss': 0.6350271701812744}
# {'epoch': 14, 'batch': 30, 'loss': 0.668728232383728}
# {'epoch': 14, 'batch': 60, 'loss': 0.6909277439117432}
# {'epoch': 14, 'batch': 90, 'loss': 0.7091173529624939}
# {'epoch': 14, 'batch': 120, 'loss': 0.738959550857544}
# {'epoch': 14, 'batch': 150, 'loss': 0.7360362410545349}
# {'epoch': 15, 'batch': 0, 'loss': 0.6004881858825684}
# {'epoch': 15, 'batch': 30, 'loss': 0.6316586136817932}
# {'epoch': 15, 'batch': 60, 'loss': 0.6295965909957886}
# {'epoch': 15, 'batch': 90, 'loss': 0.6428040266036987}
# {'epoch': 15, 'batch': 120, 'loss': 0.6777243614196777}
# {'epoch': 15, 'batch': 150, 'loss': 0.7040838003158569}
# {'epoch': 16, 'batch': 0, 'loss': 0.5825289487838745}
# {'epoch': 16, 'batch': 30, 'loss': 0.5608379244804382}
# {'epoch': 16, 'batch': 60, 'loss': 0.6052749156951904}
# {'epoch': 16, 'batch': 90, 'loss': 0.6061883568763733}
# {'epoch': 16, 'batch': 120, 'loss': 0.656665027141571}
# {'epoch': 16, 'batch': 150, 'loss': 0.6573289632797241}
# {'epoch': 17, 'batch': 0, 'loss': 0.5167909860610962}
# {'epoch': 17, 'batch': 30, 'loss': 0.541738748550415}
# {'epoch': 17, 'batch': 60, 'loss': 0.5674667954444885}
# {'epoch': 17, 'batch': 90, 'loss': 0.5728327631950378}
# {'epoch': 17, 'batch': 120, 'loss': 0.609038233757019}
# {'epoch': 17, 'batch': 150, 'loss': 0.6363890171051025}
# {'epoch': 18, 'batch': 0, 'loss': 0.5352290272712708}
# {'epoch': 18, 'batch': 30, 'loss': 0.5101452469825745}
# {'epoch': 18, 'batch': 60, 'loss': 0.5178374648094177}
# {'epoch': 18, 'batch': 90, 'loss': 0.5675034523010254}
# {'epoch': 18, 'batch': 120, 'loss': 0.5840904712677002}
# {'epoch': 18, 'batch': 150, 'loss': 0.6045758724212646}
# {'epoch': 19, 'batch': 0, 'loss': 0.47751113772392273}
# {'epoch': 19, 'batch': 30, 'loss': 0.4692055881023407}
# {'epoch': 19, 'batch': 60, 'loss': 0.4966801404953003}
# {'epoch': 19, 'batch': 90, 'loss': 0.5228387117385864}
# {'epoch': 19, 'batch': 120, 'loss': 0.5375608205795288}
# {'epoch': 19, 'batch': 150, 'loss': 0.5793675780296326}

# %%
# Visualize the loss evolution during training
plt.plot(losses)
plt.title('model loss')
plt.show()

# %% [markdown]
# ## Try the trained model
#
# Let's try again to predict some characters given the input sentence 'ROMEO:'. Now the predicted characters should be much better.

# %%
with torch.no_grad():
    input_str = 'ROMEO:'

    state = model.init_hidden(batch_size=1)
    state = state.to(device)
    data = torch.tensor([[ShakespeareDataset.char_to_index[char] for char in input_str]]).to(device)
    output, state = model(data, state)

    _, predicted_idxs = torch.max(output[0], dim = 1)
    predicted_idxs = predicted_idxs.cpu().numpy()

    predicted_str = ''.join([ShakespeareDataset.index_to_char[idx] for idx in predicted_idxs])

    print(f'Input shape: {data.size()}')
    print(f'Output shape: {data.size()}')
    print(f'Input string: {input_str}')
    print(f'Output string: {predicted_str}')
# Out:
# Input shape: torch.Size([1, 6])
# Output shape: torch.Size([1, 6])
# Input string: ROMEO:
# Output string: IMEO:

# %% [markdown]
# ## Generate new text

# %%
def predict(dataset, model, text, next_chars=1000):
    model.eval()

    chars = [char for char in text]
    state = model.init_hidden(1)
    state = state.to(device)

    # we start by feeding all the input characters to our model
    x = torch.tensor([dataset.char_to_index[char] for char in chars])
    x = x.unsqueeze(0) # create a batch of 1
    x = x.to(device)

    for i in range(0, next_chars):

        y_pred, state = model(x, state)

        last_char_logits = y_pred[0][-1]
        p = torch.nn.functional.softmax(last_char_logits, dim=0).detach().cpu().numpy()
        char_index = np.random.choice(len(last_char_logits), p=p)
        chars.append(dataset.index_to_char[char_index])

        # the output of the model (a single character index) becomes the input at next iteration
        x = torch.tensor([[char_index]])
        x = x.to(device)

    return chars

predicted = predict(ShakespeareDataset, model,'ROMEO:')
print(''.join(predicted))
# Out:
# ROMEO:
# Shall the king extremising on an ind feir course,
# Seize one to the Duke of Hereford, and willing something show
# That hour but milk out any child by him.
#
# HENRY BOLINGBROKE:
# Call forth Bagot.
# Now, fellow,
# What news it?
#
# CORIOLANUS:
# What must be band?
# If you were born so high abroad as I have fought
# With a surmitable; something stain'd with Bolingbroke's,
# And men may tensier than a younger.
#
# LUCENTIO:
# What said our part? Corse come you now! what noise?
# Then, since it like me from the honour of his hand,
# That he would laugh again in the suburber mother;
# Nothing still before a respected cousin,
# On your commonwealth from his word is call'd us.
#
# AUFIDIUS:
# Read it so;
# I am a feather for a bury to aufidius,
# Till he her for you: pray, get you home; be not advance
# The country he's confess'd it. Sir, that's a merry one.
#
# PETRUCHIO:
# Now, by being hope, here's fled from her when lady, and yet you'll descend.
#
# PAULINA:
# Good my liege, I know what I meant by an
# undischiof: for the what we will do,
# Yo

# %% [markdown]
# While some of the sentences are grammatically correct, most do not make sense. The model has not learned the meaning of words (we would need a much larger corpus for that, and probably a word level language model), but consider the following:
#
# * The model is character-based. When training started, the model did not know how to spell an English word, or that words were even a unit of text. Now it does a pretty decent job on spelling.
#
# * The structure of the output resembles a play, blocks of text generally begin with a speaker name, in all capital letters similar to the dataset.
#
# * The model is trained on small batches of text (100 characters each), and is still able to generate a longer sequence of text with coherent structure.

# %% [markdown]
# # Homework
#
# <span style="color:blue">
#
# **Exercise 3:** Build two new models: one using Simple RNN cells (torch.nn.RNN) instead of GRUs(torch.nn.RNN), and the other using LSTMs (torch.nn.LSTM). Train all three models (GRU, LSTM, SimpleRNN) for 30 epochs and compare the loss curves. You can optionally try different configurations: embedding dimension, hidden layers dimensions, number of layers, etc.
#
# </span>

# %%
# GRU
num_epochs = 30

losses_GRU = train(train_loader, model, batch_size, sequence_length, num_epochs)
# Out:
# {'epoch': 0, 'batch': 0, 'loss': 4.176522731781006}
# {'epoch': 0, 'batch': 30, 'loss': 2.2526588439941406}
# {'epoch': 0, 'batch': 60, 'loss': 1.9289648532867432}
# {'epoch': 0, 'batch': 90, 'loss': 1.7788255214691162}
# {'epoch': 0, 'batch': 120, 'loss': 1.6895267963409424}
# {'epoch': 0, 'batch': 150, 'loss': 1.586256504058838}
# {'epoch': 1, 'batch': 0, 'loss': 1.50981867313385}
# {'epoch': 1, 'batch': 30, 'loss': 1.4492180347442627}
# {'epoch': 1, 'batch': 60, 'loss': 1.4538160562515259}
# {'epoch': 1, 'batch': 90, 'loss': 1.4657472372055054}
# {'epoch': 1, 'batch': 120, 'loss': 1.3952903747558594}
# {'epoch': 1, 'batch': 150, 'loss': 1.416853427886963}
# {'epoch': 2, 'batch': 0, 'loss': 1.3755205869674683}
# {'epoch': 2, 'batch': 30, 'loss': 1.3191992044448853}
# {'epoch': 2, 'batch': 60, 'loss': 1.338541865348816}
# {'epoch': 2, 'batch': 90, 'loss': 1.3260083198547363}
# {'epoch': 2, 'batch': 120, 'loss': 1.3118221759796143}
# {'epoch': 2, 'batch': 150, 'loss': 1.3418291807174683}
# {'epoch': 3, 'batch': 0, 'loss': 1.2643095254898071}
# {'epoch': 3, 'batch': 30, 'loss': 1.2907644510269165}
# {'epoch': 3, 'batch': 60, 'loss': 1.288741111755371}
# {'epoch': 3, 'batch': 90, 'loss': 1.312556266784668}
# {'epoch': 3, 'batch': 120, 'loss': 1.2320750951766968}
# {'epoch': 3, 'batch': 150, 'loss': 1.2731826305389404}
# {'epoch': 4, 'batch': 0, 'loss': 1.2150079011917114}
# {'epoch': 4, 'batch': 30, 'loss': 1.2307705879211426}
# {'epoch': 4, 'batch': 60, 'loss': 1.2451999187469482}
# {'epoch': 4, 'batch': 90, 'loss': 1.2218596935272217}
# {'epoch': 4, 'batch': 120, 'loss': 1.1890584230422974}
# {'epoch': 4, 'batch': 150, 'loss': 1.2678234577178955}
# {'epoch': 5, 'batch': 0, 'loss': 1.1618585586547852}
# {'epoch': 5, 'batch': 30, 'loss': 1.1592202186584473}
# {'epoch': 5, 'batch': 60, 'loss': 1.1515363454818726}
# {'epoch': 5, 'batch': 90, 'loss': 1.2026845216751099}
# {'epoch': 5, 'batch': 120, 'loss': 1.1793442964553833}
# {'epoch': 5, 'batch': 150, 'loss': 1.1700019836425781}
# {'epoch': 6, 'batch': 0, 'loss': 1.1296820640563965}
# {'epoch': 6, 'batch': 30, 'loss': 1.1169555187225342}
# {'epoch': 6, 'batch': 60, 'loss': 1.137068271636963}
# {'epoch': 6, 'batch': 90, 'loss': 1.1462905406951904}
# {'epoch': 6, 'batch': 120, 'loss': 1.1371182203292847}
# {'epoch': 6, 'batch': 150, 'loss': 1.1465801000595093}
# {'epoch': 7, 'batch': 0, 'loss': 1.0561922788619995}
# {'epoch': 7, 'batch': 30, 'loss': 1.055201530456543}
# {'epoch': 7, 'batch': 60, 'loss': 1.0866179466247559}
# {'epoch': 7, 'batch': 90, 'loss': 1.1048022508621216}
# {'epoch': 7, 'batch': 120, 'loss': 1.0897877216339111}
# {'epoch': 7, 'batch': 150, 'loss': 1.075364112854004}
# {'epoch': 8, 'batch': 0, 'loss': 0.9899490475654602}
# {'epoch': 8, 'batch': 30, 'loss': 1.0051020383834839}
# {'epoch': 8, 'batch': 60, 'loss': 1.029638648033142}
# {'epoch': 8, 'batch': 90, 'loss': 1.0086251497268677}
# {'epoch': 8, 'batch': 120, 'loss': 1.0482559204101562}
# {'epoch': 8, 'batch': 150, 'loss': 1.0248355865478516}
# {'epoch': 9, 'batch': 0, 'loss': 0.9572340250015259}
# {'epoch': 9, 'batch': 30, 'loss': 0.9111549258232117}
# {'epoch': 9, 'batch': 60, 'loss': 0.9575017690658569}
# {'epoch': 9, 'batch': 90, 'loss': 0.995430588722229}
# {'epoch': 9, 'batch': 120, 'loss': 0.9841065406799316}
# {'epoch': 9, 'batch': 150, 'loss': 1.005854606628418}
# {'epoch': 10, 'batch': 0, 'loss': 0.8909993767738342}
# {'epoch': 10, 'batch': 30, 'loss': 0.8929628133773804}
# {'epoch': 10, 'batch': 60, 'loss': 0.8918757438659668}
# {'epoch': 10, 'batch': 90, 'loss': 0.9294447898864746}
# {'epoch': 10, 'batch': 120, 'loss': 0.9468991756439209}
# {'epoch': 10, 'batch': 150, 'loss': 0.9474650025367737}
# {'epoch': 11, 'batch': 0, 'loss': 0.8253581523895264}
# {'epoch': 11, 'batch': 30, 'loss': 0.8131820559501648}
# {'epoch': 11, 'batch': 60, 'loss': 0.8406657576560974}
# {'epoch': 11, 'batch': 90, 'loss': 0.8747113943099976}
# {'epoch': 11, 'batch': 120, 'loss': 0.8883730173110962}
# {'epoch': 11, 'batch': 150, 'loss': 0.8838549256324768}
# {'epoch': 12, 'batch': 0, 'loss': 0.7759425640106201}
# {'epoch': 12, 'batch': 30, 'loss': 0.7763850688934326}
# {'epoch': 12, 'batch': 60, 'loss': 0.7827749848365784}
# {'epoch': 12, 'batch': 90, 'loss': 0.829618513584137}
# {'epoch': 12, 'batch': 120, 'loss': 0.8418958783149719}
# {'epoch': 12, 'batch': 150, 'loss': 0.8586358428001404}
# {'epoch': 13, 'batch': 0, 'loss': 0.7261604070663452}
# {'epoch': 13, 'batch': 30, 'loss': 0.7030863761901855}
# {'epoch': 13, 'batch': 60, 'loss': 0.7396112680435181}
# {'epoch': 13, 'batch': 90, 'loss': 0.7682653069496155}
# {'epoch': 13, 'batch': 120, 'loss': 0.7818173766136169}
# {'epoch': 13, 'batch': 150, 'loss': 0.8041580319404602}
# {'epoch': 14, 'batch': 0, 'loss': 0.6615015268325806}
# {'epoch': 14, 'batch': 30, 'loss': 0.6502948999404907}
# {'epoch': 14, 'batch': 60, 'loss': 0.6875499486923218}
# {'epoch': 14, 'batch': 90, 'loss': 0.7125421166419983}
# {'epoch': 14, 'batch': 120, 'loss': 0.727277398109436}
# {'epoch': 14, 'batch': 150, 'loss': 0.7413845658302307}
# {'epoch': 15, 'batch': 0, 'loss': 0.6391808986663818}
# {'epoch': 15, 'batch': 30, 'loss': 0.6152492761611938}
# {'epoch': 15, 'batch': 60, 'loss': 0.6096071004867554}
# {'epoch': 15, 'batch': 90, 'loss': 0.6666079759597778}
# {'epoch': 15, 'batch': 120, 'loss': 0.7004287838935852}
# {'epoch': 15, 'batch': 150, 'loss': 0.7362163662910461}
# {'epoch': 16, 'batch': 0, 'loss': 0.5730506777763367}
# {'epoch': 16, 'batch': 30, 'loss': 0.5715688467025757}
# {'epoch': 16, 'batch': 60, 'loss': 0.5957608222961426}
# {'epoch': 16, 'batch': 90, 'loss': 0.6197888851165771}
# {'epoch': 16, 'batch': 120, 'loss': 0.6352491974830627}
# {'epoch': 16, 'batch': 150, 'loss': 0.6763079166412354}
# {'epoch': 17, 'batch': 0, 'loss': 0.5506759881973267}
# {'epoch': 17, 'batch': 30, 'loss': 0.5516401529312134}
# {'epoch': 17, 'batch': 60, 'loss': 0.5589404702186584}
# {'epoch': 17, 'batch': 90, 'loss': 0.5787005424499512}
# {'epoch': 17, 'batch': 120, 'loss': 0.6075358390808105}
# {'epoch': 17, 'batch': 150, 'loss': 0.6344398260116577}
# {'epoch': 18, 'batch': 0, 'loss': 0.503492534160614}
# {'epoch': 18, 'batch': 30, 'loss': 0.5087921023368835}
# {'epoch': 18, 'batch': 60, 'loss': 0.537747323513031}
# {'epoch': 18, 'batch': 90, 'loss': 0.5470482110977173}
# {'epoch': 18, 'batch': 120, 'loss': 0.564298689365387}
# {'epoch': 18, 'batch': 150, 'loss': 0.6094253659248352}
# {'epoch': 19, 'batch': 0, 'loss': 0.49502429366111755}
# {'epoch': 19, 'batch': 30, 'loss': 0.4996572732925415}
# {'epoch': 19, 'batch': 60, 'loss': 0.49943435192108154}
# {'epoch': 19, 'batch': 90, 'loss': 0.5295140743255615}
# {'epoch': 19, 'batch': 120, 'loss': 0.5574944019317627}
# {'epoch': 19, 'batch': 150, 'loss': 0.5908134579658508}
# {'epoch': 20, 'batch': 0, 'loss': 0.45322006940841675}
# {'epoch': 20, 'batch': 30, 'loss': 0.471182256937027}
# {'epoch': 20, 'batch': 60, 'loss': 0.49434712529182434}
# {'epoch': 20, 'batch': 90, 'loss': 0.5115083456039429}
# {'epoch': 20, 'batch': 120, 'loss': 0.5189871191978455}
# {'epoch': 20, 'batch': 150, 'loss': 0.5766534209251404}
# {'epoch': 21, 'batch': 0, 'loss': 0.43647369742393494}
# {'epoch': 21, 'batch': 30, 'loss': 0.43803733587265015}
# {'epoch': 21, 'batch': 60, 'loss': 0.48360657691955566}
# {'epoch': 21, 'batch': 90, 'loss': 0.499111533164978}
# {'epoch': 21, 'batch': 120, 'loss': 0.5280285477638245}
# {'epoch': 21, 'batch': 150, 'loss': 0.5526777505874634}
# {'epoch': 22, 'batch': 0, 'loss': 0.4212278127670288}
# {'epoch': 22, 'batch': 30, 'loss': 0.43330252170562744}
# {'epoch': 22, 'batch': 60, 'loss': 0.4391566216945648}
# {'epoch': 22, 'batch': 90, 'loss': 0.4804055392742157}
# {'epoch': 22, 'batch': 120, 'loss': 0.49698886275291443}
# {'epoch': 22, 'batch': 150, 'loss': 0.5292844176292419}
# {'epoch': 23, 'batch': 0, 'loss': 0.4135330319404602}
# {'epoch': 23, 'batch': 30, 'loss': 0.41383475065231323}
# {'epoch': 23, 'batch': 60, 'loss': 0.44541454315185547}
# {'epoch': 23, 'batch': 90, 'loss': 0.4723028540611267}
# {'epoch': 23, 'batch': 120, 'loss': 0.49079617857933044}
# {'epoch': 23, 'batch': 150, 'loss': 0.5158947706222534}
# {'epoch': 24, 'batch': 0, 'loss': 0.4086761474609375}
# {'epoch': 24, 'batch': 30, 'loss': 0.4068432152271271}
# {'epoch': 24, 'batch': 60, 'loss': 0.43073299527168274}
# {'epoch': 24, 'batch': 90, 'loss': 0.4583350121974945}
# {'epoch': 24, 'batch': 120, 'loss': 0.48235827684402466}
# {'epoch': 24, 'batch': 150, 'loss': 0.49757903814315796}
# {'epoch': 25, 'batch': 0, 'loss': 0.4038182199001312}
# {'epoch': 25, 'batch': 30, 'loss': 0.434865802526474}
# {'epoch': 25, 'batch': 60, 'loss': 0.42547714710235596}
# {'epoch': 25, 'batch': 90, 'loss': 0.4628683924674988}
# {'epoch': 25, 'batch': 120, 'loss': 0.481637567281723}
# {'epoch': 25, 'batch': 150, 'loss': 0.4851343631744385}
# {'epoch': 26, 'batch': 0, 'loss': 0.40277817845344543}
# {'epoch': 26, 'batch': 30, 'loss': 0.40638530254364014}
# {'epoch': 26, 'batch': 60, 'loss': 0.42670348286628723}
# {'epoch': 26, 'batch': 90, 'loss': 0.43933460116386414}
# {'epoch': 26, 'batch': 120, 'loss': 0.46138840913772583}
# {'epoch': 26, 'batch': 150, 'loss': 0.5087761878967285}
# {'epoch': 27, 'batch': 0, 'loss': 0.39163482189178467}
# {'epoch': 27, 'batch': 30, 'loss': 0.4217297434806824}
# {'epoch': 27, 'batch': 60, 'loss': 0.43024566769599915}
# {'epoch': 27, 'batch': 90, 'loss': 0.4375087320804596}
# {'epoch': 27, 'batch': 120, 'loss': 0.482509046792984}
# {'epoch': 27, 'batch': 150, 'loss': 0.5153536796569824}
# {'epoch': 28, 'batch': 0, 'loss': 0.37337592244148254}
# {'epoch': 28, 'batch': 30, 'loss': 0.4073658883571625}
# {'epoch': 28, 'batch': 60, 'loss': 0.42740967869758606}
# {'epoch': 28, 'batch': 90, 'loss': 0.46482327580451965}
# {'epoch': 28, 'batch': 120, 'loss': 0.4732494354248047}
# {'epoch': 28, 'batch': 150, 'loss': 0.4942189157009125}
# {'epoch': 29, 'batch': 0, 'loss': 0.4043554663658142}
# {'epoch': 29, 'batch': 30, 'loss': 0.4108533561229706}
# {'epoch': 29, 'batch': 60, 'loss': 0.4222596287727356}
# {'epoch': 29, 'batch': 90, 'loss': 0.4659339487552643}
# {'epoch': 29, 'batch': 120, 'loss': 0.46932709217071533}
# {'epoch': 29, 'batch': 150, 'loss': 0.49601319432258606}

# %%
# RNN
class ModelRNN(nn.Module):
    def __init__(self, input_dim, embedding_dim, hidden_dim, output_dim, n_layers, drop_prob=0.):
        super(ModelRNN, self).__init__()
        self.hidden_dim = hidden_dim
        self.n_layers = n_layers

        # YOUR CODE HERE
        self.embedding = torch.nn.Embedding(num_embeddings = input_dim, embedding_dim = embedding_dim)
        self.rnn = torch.nn.RNN(input_size = embedding_dim, hidden_size = hidden_dim, num_layers = n_layers, batch_first=True)
        self.fc = torch.nn.Linear(in_features = hidden_dim, out_features = output_dim)


    def forward(self, x, h):
        emb = self.embedding(x)
        out, h = self.rnn(emb, h)
        out = self.fc(out)
        return out, h

    def init_hidden(self, batch_size):
        " Initialize the hidden state of the RNN to zeros"
        hidden = nn.Parameter(torch.zeros(self.n_layers, batch_size, self.hidden_dim))
        return hidden

# %%
modelRNN = ModelRNN(input_dim, embedding_dim, hidden_dim, output_dim, n_layers, drop_prob).to(device)
print(modelRNN)

losses_RNN = train(train_loader, modelRNN, batch_size, sequence_length, num_epochs)
# Out:
# ModelRNN(
#   (embedding): Embedding(65, 300)
#   (rnn): RNN(300, 1024, num_layers=2, batch_first=True)
#   (fc): Linear(in_features=1024, out_features=65, bias=True)
# )
# {'epoch': 0, 'batch': 0, 'loss': 4.178610324859619}
# {'epoch': 0, 'batch': 30, 'loss': 2.2354190349578857}
# {'epoch': 0, 'batch': 60, 'loss': 1.9857133626937866}
# {'epoch': 0, 'batch': 90, 'loss': 1.8662419319152832}
# {'epoch': 0, 'batch': 120, 'loss': 1.7642877101898193}
# {'epoch': 0, 'batch': 150, 'loss': 1.660097599029541}
# {'epoch': 1, 'batch': 0, 'loss': 1.6465531587600708}
# {'epoch': 1, 'batch': 30, 'loss': 1.6297271251678467}
# {'epoch': 1, 'batch': 60, 'loss': 1.5537103414535522}
# {'epoch': 1, 'batch': 90, 'loss': 1.5416592359542847}
# {'epoch': 1, 'batch': 120, 'loss': 1.5052014589309692}
# {'epoch': 1, 'batch': 150, 'loss': 1.5653297901153564}
# {'epoch': 2, 'batch': 0, 'loss': 1.4289497137069702}
# {'epoch': 2, 'batch': 30, 'loss': 1.4723153114318848}
# {'epoch': 2, 'batch': 60, 'loss': 1.4731073379516602}
# {'epoch': 2, 'batch': 90, 'loss': 1.4474619626998901}
# {'epoch': 2, 'batch': 120, 'loss': 1.4275410175323486}
# {'epoch': 2, 'batch': 150, 'loss': 1.4082814455032349}
# {'epoch': 3, 'batch': 0, 'loss': 1.3937404155731201}
# {'epoch': 3, 'batch': 30, 'loss': 1.4064092636108398}
# {'epoch': 3, 'batch': 60, 'loss': 1.395110011100769}
# {'epoch': 3, 'batch': 90, 'loss': 1.3799694776535034}
# {'epoch': 3, 'batch': 120, 'loss': 1.436639428138733}
# {'epoch': 3, 'batch': 150, 'loss': 1.3937225341796875}
# {'epoch': 4, 'batch': 0, 'loss': 1.3125087022781372}
# {'epoch': 4, 'batch': 30, 'loss': 1.3725777864456177}
# {'epoch': 4, 'batch': 60, 'loss': 1.3588355779647827}
# {'epoch': 4, 'batch': 90, 'loss': 1.354390263557434}
# {'epoch': 4, 'batch': 120, 'loss': 1.4025150537490845}
# {'epoch': 4, 'batch': 150, 'loss': 1.3500971794128418}
# {'epoch': 5, 'batch': 0, 'loss': 1.2907160520553589}
# {'epoch': 5, 'batch': 30, 'loss': 1.3082672357559204}
# {'epoch': 5, 'batch': 60, 'loss': 1.3490171432495117}
# {'epoch': 5, 'batch': 90, 'loss': 1.3272126913070679}
# {'epoch': 5, 'batch': 120, 'loss': 1.2868815660476685}
# {'epoch': 5, 'batch': 150, 'loss': 1.3660149574279785}
# {'epoch': 6, 'batch': 0, 'loss': 1.2851449251174927}
# {'epoch': 6, 'batch': 30, 'loss': 1.2896223068237305}
# {'epoch': 6, 'batch': 60, 'loss': 1.2814898490905762}
# {'epoch': 6, 'batch': 90, 'loss': 1.2724653482437134}
# {'epoch': 6, 'batch': 120, 'loss': 1.2990984916687012}
# {'epoch': 6, 'batch': 150, 'loss': 1.312056303024292}
# {'epoch': 7, 'batch': 0, 'loss': 1.2493293285369873}
# {'epoch': 7, 'batch': 30, 'loss': 1.2690833806991577}
# {'epoch': 7, 'batch': 60, 'loss': 1.255569338798523}
# {'epoch': 7, 'batch': 90, 'loss': 1.3221157789230347}
# {'epoch': 7, 'batch': 120, 'loss': 1.2715442180633545}
# {'epoch': 7, 'batch': 150, 'loss': 1.254022479057312}
# {'epoch': 8, 'batch': 0, 'loss': 1.2469208240509033}
# {'epoch': 8, 'batch': 30, 'loss': 1.2507396936416626}
# {'epoch': 8, 'batch': 60, 'loss': 1.262174367904663}
# {'epoch': 8, 'batch': 90, 'loss': 1.242753505706787}
# {'epoch': 8, 'batch': 120, 'loss': 1.2504887580871582}
# {'epoch': 8, 'batch': 150, 'loss': 1.248282790184021}
# {'epoch': 9, 'batch': 0, 'loss': 1.1950377225875854}
# {'epoch': 9, 'batch': 30, 'loss': 1.1851511001586914}
# {'epoch': 9, 'batch': 60, 'loss': 1.2424633502960205}
# {'epoch': 9, 'batch': 90, 'loss': 1.2277060747146606}
# {'epoch': 9, 'batch': 120, 'loss': 1.244057059288025}
# {'epoch': 9, 'batch': 150, 'loss': 1.2398560047149658}
# {'epoch': 10, 'batch': 0, 'loss': 1.167524814605713}
# {'epoch': 10, 'batch': 30, 'loss': 1.1555746793746948}
# {'epoch': 10, 'batch': 60, 'loss': 1.1794421672821045}
# {'epoch': 10, 'batch': 90, 'loss': 1.2024379968643188}
# {'epoch': 10, 'batch': 120, 'loss': 1.2128500938415527}
# {'epoch': 10, 'batch': 150, 'loss': 1.2159584760665894}
# {'epoch': 11, 'batch': 0, 'loss': 1.1452844142913818}
# {'epoch': 11, 'batch': 30, 'loss': 1.1466251611709595}
# {'epoch': 11, 'batch': 60, 'loss': 1.193803310394287}
# {'epoch': 11, 'batch': 90, 'loss': 1.1709723472595215}
# {'epoch': 11, 'batch': 120, 'loss': 1.1890803575515747}
# {'epoch': 11, 'batch': 150, 'loss': 1.190692663192749}
# {'epoch': 12, 'batch': 0, 'loss': 1.1659541130065918}
# {'epoch': 12, 'batch': 30, 'loss': 1.1350164413452148}
# {'epoch': 12, 'batch': 60, 'loss': 1.1808418035507202}
# {'epoch': 12, 'batch': 90, 'loss': 1.1464166641235352}
# {'epoch': 12, 'batch': 120, 'loss': 1.1685885190963745}
# {'epoch': 12, 'batch': 150, 'loss': 1.208715796470642}
# {'epoch': 13, 'batch': 0, 'loss': 1.1551413536071777}
# {'epoch': 13, 'batch': 30, 'loss': 1.0982061624526978}
# {'epoch': 13, 'batch': 60, 'loss': 1.1513687372207642}
# {'epoch': 13, 'batch': 90, 'loss': 1.1273330450057983}
# {'epoch': 13, 'batch': 120, 'loss': 1.1452312469482422}
# {'epoch': 13, 'batch': 150, 'loss': 1.2085678577423096}
# {'epoch': 14, 'batch': 0, 'loss': 1.0857441425323486}
# {'epoch': 14, 'batch': 30, 'loss': 1.1082677841186523}
# {'epoch': 14, 'batch': 60, 'loss': 1.113132119178772}
# {'epoch': 14, 'batch': 90, 'loss': 1.1443454027175903}
# {'epoch': 14, 'batch': 120, 'loss': 1.129860281944275}
# {'epoch': 14, 'batch': 150, 'loss': 1.1252694129943848}
# {'epoch': 15, 'batch': 0, 'loss': 1.0709643363952637}
# {'epoch': 15, 'batch': 30, 'loss': 1.1229922771453857}
# {'epoch': 15, 'batch': 60, 'loss': 1.1019983291625977}
# {'epoch': 15, 'batch': 90, 'loss': 1.1002302169799805}
# {'epoch': 15, 'batch': 120, 'loss': 1.126406192779541}
# {'epoch': 15, 'batch': 150, 'loss': 1.128410816192627}
# {'epoch': 16, 'batch': 0, 'loss': 1.0392005443572998}
# {'epoch': 16, 'batch': 30, 'loss': 1.0570998191833496}
# {'epoch': 16, 'batch': 60, 'loss': 1.0866646766662598}
# {'epoch': 16, 'batch': 90, 'loss': 1.0912343263626099}
# {'epoch': 16, 'batch': 120, 'loss': 1.101131558418274}
# {'epoch': 16, 'batch': 150, 'loss': 1.1226385831832886}
# {'epoch': 17, 'batch': 0, 'loss': 1.0517147779464722}
# {'epoch': 17, 'batch': 30, 'loss': 1.0454912185668945}
# {'epoch': 17, 'batch': 60, 'loss': 1.0615829229354858}
# {'epoch': 17, 'batch': 90, 'loss': 1.0876730680465698}
# {'epoch': 17, 'batch': 120, 'loss': 1.0471665859222412}
# {'epoch': 17, 'batch': 150, 'loss': 1.0663158893585205}
# {'epoch': 18, 'batch': 0, 'loss': 1.0735613107681274}
# {'epoch': 18, 'batch': 30, 'loss': 1.0626670122146606}
# {'epoch': 18, 'batch': 60, 'loss': 1.0672566890716553}
# {'epoch': 18, 'batch': 90, 'loss': 1.0208815336227417}
# {'epoch': 18, 'batch': 120, 'loss': 1.0588208436965942}
# {'epoch': 18, 'batch': 150, 'loss': 1.083408236503601}
# {'epoch': 19, 'batch': 0, 'loss': 1.0021575689315796}
# {'epoch': 19, 'batch': 30, 'loss': 1.0031139850616455}
# {'epoch': 19, 'batch': 60, 'loss': 1.0258880853652954}
# {'epoch': 19, 'batch': 90, 'loss': 1.067033290863037}
# {'epoch': 19, 'batch': 120, 'loss': 1.0339345932006836}
# {'epoch': 19, 'batch': 150, 'loss': 1.0620403289794922}
# {'epoch': 20, 'batch': 0, 'loss': 1.0075105428695679}
# {'epoch': 20, 'batch': 30, 'loss': 1.002874493598938}
# {'epoch': 20, 'batch': 60, 'loss': 1.0115275382995605}
# {'epoch': 20, 'batch': 90, 'loss': 1.0346033573150635}
# {'epoch': 20, 'batch': 120, 'loss': 1.0291743278503418}
# {'epoch': 20, 'batch': 150, 'loss': 1.044713020324707}
# {'epoch': 21, 'batch': 0, 'loss': 0.9792599678039551}
# {'epoch': 21, 'batch': 30, 'loss': 0.9982356429100037}
# {'epoch': 21, 'batch': 60, 'loss': 0.995483934879303}
# {'epoch': 21, 'batch': 90, 'loss': 0.9977529644966125}
# {'epoch': 21, 'batch': 120, 'loss': 1.0039291381835938}
# {'epoch': 21, 'batch': 150, 'loss': 1.0353652238845825}
# {'epoch': 22, 'batch': 0, 'loss': 0.9620224237442017}
# {'epoch': 22, 'batch': 30, 'loss': 0.9902547597885132}
# {'epoch': 22, 'batch': 60, 'loss': 0.9884670972824097}
# {'epoch': 22, 'batch': 90, 'loss': 0.9938876628875732}
# {'epoch': 22, 'batch': 120, 'loss': 1.0167365074157715}
# {'epoch': 22, 'batch': 150, 'loss': 1.0295478105545044}
# {'epoch': 23, 'batch': 0, 'loss': 0.951546311378479}
# {'epoch': 23, 'batch': 30, 'loss': 0.9884354472160339}
# {'epoch': 23, 'batch': 60, 'loss': 1.007065773010254}
# {'epoch': 23, 'batch': 90, 'loss': 0.9754902124404907}
# {'epoch': 23, 'batch': 120, 'loss': 1.0224686861038208}
# {'epoch': 23, 'batch': 150, 'loss': 0.9987085461616516}
# {'epoch': 24, 'batch': 0, 'loss': 0.953522801399231}
# {'epoch': 24, 'batch': 30, 'loss': 0.9647589921951294}
# {'epoch': 24, 'batch': 60, 'loss': 0.9615066647529602}
# {'epoch': 24, 'batch': 90, 'loss': 0.9796978235244751}
# {'epoch': 24, 'batch': 120, 'loss': 1.020559310913086}
# {'epoch': 24, 'batch': 150, 'loss': 1.0111396312713623}
# {'epoch': 25, 'batch': 0, 'loss': 0.9059630632400513}
# {'epoch': 25, 'batch': 30, 'loss': 0.9405238628387451}
# {'epoch': 25, 'batch': 60, 'loss': 0.9610456228256226}
# {'epoch': 25, 'batch': 90, 'loss': 0.9652770757675171}
# {'epoch': 25, 'batch': 120, 'loss': 0.9997727870941162}
# {'epoch': 25, 'batch': 150, 'loss': 1.0334666967391968}
# {'epoch': 26, 'batch': 0, 'loss': 0.9158554077148438}
# {'epoch': 26, 'batch': 30, 'loss': 0.9312863945960999}
# {'epoch': 26, 'batch': 60, 'loss': 0.9503118991851807}
# {'epoch': 26, 'batch': 90, 'loss': 0.9631657600402832}
# {'epoch': 26, 'batch': 120, 'loss': 0.9690115451812744}
# {'epoch': 26, 'batch': 150, 'loss': 0.9872940182685852}
# {'epoch': 27, 'batch': 0, 'loss': 0.9227192401885986}
# {'epoch': 27, 'batch': 30, 'loss': 0.9215365648269653}
# {'epoch': 27, 'batch': 60, 'loss': 0.9441096782684326}
# {'epoch': 27, 'batch': 90, 'loss': 0.9369493126869202}
# {'epoch': 27, 'batch': 120, 'loss': 0.9715139269828796}
# {'epoch': 27, 'batch': 150, 'loss': 0.9918038249015808}
# {'epoch': 28, 'batch': 0, 'loss': 0.9320768713951111}
# {'epoch': 28, 'batch': 30, 'loss': 0.9262331128120422}
# {'epoch': 28, 'batch': 60, 'loss': 0.9406566023826599}
# {'epoch': 28, 'batch': 90, 'loss': 0.9613407850265503}
# {'epoch': 28, 'batch': 120, 'loss': 0.9577763080596924}
# {'epoch': 28, 'batch': 150, 'loss': 0.9637442231178284}
# {'epoch': 29, 'batch': 0, 'loss': 0.8894279599189758}
# {'epoch': 29, 'batch': 30, 'loss': 0.909848690032959}
# {'epoch': 29, 'batch': 60, 'loss': 0.920329749584198}
# {'epoch': 29, 'batch': 90, 'loss': 0.9198471903800964}
# {'epoch': 29, 'batch': 120, 'loss': 0.9382576942443848}
# {'epoch': 29, 'batch': 150, 'loss': 0.9613863229751587}

# %%
class ModelLSTM(nn.Module):
    def __init__(self, input_dim, embedding_dim, hidden_dim, output_dim, n_layers, drop_prob=0.):
        super(ModelLSTM, self).__init__()
        self.hidden_dim = hidden_dim
        self.n_layers = n_layers

        self.embedding = nn.Embedding(num_embeddings=input_dim, embedding_dim=embedding_dim)
        self.lstm = nn.LSTM(input_size=embedding_dim, hidden_size=hidden_dim, num_layers=n_layers, batch_first=True)
        self.fc = nn.Linear(in_features=hidden_dim, out_features=output_dim)

    def forward(self, x, h):
        emb = self.embedding(x)
        out, h = self.lstm(emb, h)
        out = self.fc(out)
        return out, h

    def init_hidden(self, batch_size):
        # Initialize the hidden state of the LSTM to zeros
        hidden = torch.zeros(self.n_layers, batch_size, self.hidden_dim).to(device)
        cell = torch.zeros(self.n_layers, batch_size, self.hidden_dim).to(device)
        return hidden, cell

def trainLSTM(dataloader, model, batch_size, sequence_length, num_epochs):
    model.train()

    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=0.001)

    losses = []
    for epoch in range(num_epochs):
        for batch, (x, y) in enumerate(dataloader):
            # Initialize hidden state for each batch
            hidden, cell = model.init_hidden(batch_size)

            # Move tensors to the appropriate device
            x = x.to(device)
            y = y.to(device)
            hidden = hidden.to(device)
            cell = cell.to(device)

            # Zero the gradients
            optimizer.zero_grad()

            # Forward pass
            y_pred, (hidden, cell) = model(x, (hidden, cell))

            # Compute loss
            loss = criterion(y_pred.transpose(1, 2), y)

            # Backward pass and optimization
            loss.backward()
            optimizer.step()


            # Print every 30 batches
            if batch % 30 == 0:
                print({ 'epoch': epoch, 'batch': batch, 'loss': loss.item() })
                # Track the training loss
                losses.append(loss.item())

    return losses

# %%
modelLSTM = ModelLSTM(input_dim, embedding_dim, hidden_dim, output_dim, n_layers, drop_prob).to(device)
print(modelRNN)

losses_LSTM = trainLSTM(train_loader, modelLSTM, batch_size, sequence_length, num_epochs)
# Out:
# ModelRNN(
#   (embedding): Embedding(65, 300)
#   (rnn): RNN(300, 1024, num_layers=2, batch_first=True)
#   (fc): Linear(in_features=1024, out_features=65, bias=True)
# )
# {'epoch': 0, 'batch': 0, 'loss': 4.174380302429199}
# {'epoch': 0, 'batch': 30, 'loss': 2.2977399826049805}
# {'epoch': 0, 'batch': 60, 'loss': 1.94919753074646}
# {'epoch': 0, 'batch': 90, 'loss': 1.786899447441101}
# {'epoch': 0, 'batch': 120, 'loss': 1.6686460971832275}
# {'epoch': 0, 'batch': 150, 'loss': 1.6064907312393188}
# {'epoch': 1, 'batch': 0, 'loss': 1.5269511938095093}
# {'epoch': 1, 'batch': 30, 'loss': 1.4717040061950684}
# {'epoch': 1, 'batch': 60, 'loss': 1.4738682508468628}
# {'epoch': 1, 'batch': 90, 'loss': 1.4169151782989502}
# {'epoch': 1, 'batch': 120, 'loss': 1.3677095174789429}
# {'epoch': 1, 'batch': 150, 'loss': 1.4259449243545532}
# {'epoch': 2, 'batch': 0, 'loss': 1.3214184045791626}
# {'epoch': 2, 'batch': 30, 'loss': 1.2954219579696655}
# {'epoch': 2, 'batch': 60, 'loss': 1.3698747158050537}
# {'epoch': 2, 'batch': 90, 'loss': 1.335962176322937}
# {'epoch': 2, 'batch': 120, 'loss': 1.3136804103851318}
# {'epoch': 2, 'batch': 150, 'loss': 1.356696605682373}
# {'epoch': 3, 'batch': 0, 'loss': 1.2833421230316162}
# {'epoch': 3, 'batch': 30, 'loss': 1.2196952104568481}
# {'epoch': 3, 'batch': 60, 'loss': 1.2686766386032104}
# {'epoch': 3, 'batch': 90, 'loss': 1.3169041872024536}
# {'epoch': 3, 'batch': 120, 'loss': 1.2692372798919678}
# {'epoch': 3, 'batch': 150, 'loss': 1.2415868043899536}
# {'epoch': 4, 'batch': 0, 'loss': 1.1967564821243286}
# {'epoch': 4, 'batch': 30, 'loss': 1.177927017211914}
# {'epoch': 4, 'batch': 60, 'loss': 1.1990007162094116}
# {'epoch': 4, 'batch': 90, 'loss': 1.2066917419433594}
# {'epoch': 4, 'batch': 120, 'loss': 1.219420075416565}
# {'epoch': 4, 'batch': 150, 'loss': 1.2181435823440552}
# {'epoch': 5, 'batch': 0, 'loss': 1.1452302932739258}
# {'epoch': 5, 'batch': 30, 'loss': 1.1403099298477173}
# {'epoch': 5, 'batch': 60, 'loss': 1.148328185081482}
# {'epoch': 5, 'batch': 90, 'loss': 1.152116298675537}
# {'epoch': 5, 'batch': 120, 'loss': 1.1792895793914795}
# {'epoch': 5, 'batch': 150, 'loss': 1.1789346933364868}
# {'epoch': 6, 'batch': 0, 'loss': 1.0822041034698486}
# {'epoch': 6, 'batch': 30, 'loss': 1.108718991279602}
# {'epoch': 6, 'batch': 60, 'loss': 1.0975086688995361}
# {'epoch': 6, 'batch': 90, 'loss': 1.0749351978302002}
# {'epoch': 6, 'batch': 120, 'loss': 1.1410925388336182}
# {'epoch': 6, 'batch': 150, 'loss': 1.1144542694091797}
# {'epoch': 7, 'batch': 0, 'loss': 1.0243570804595947}
# {'epoch': 7, 'batch': 30, 'loss': 0.9975032210350037}
# {'epoch': 7, 'batch': 60, 'loss': 1.0251976251602173}
# {'epoch': 7, 'batch': 90, 'loss': 1.0487653017044067}
# {'epoch': 7, 'batch': 120, 'loss': 1.0464591979980469}
# {'epoch': 7, 'batch': 150, 'loss': 1.0952681303024292}
# {'epoch': 8, 'batch': 0, 'loss': 0.9623777270317078}
# {'epoch': 8, 'batch': 30, 'loss': 0.9726017117500305}
# {'epoch': 8, 'batch': 60, 'loss': 0.970059871673584}
# {'epoch': 8, 'batch': 90, 'loss': 0.9855246543884277}
# {'epoch': 8, 'batch': 120, 'loss': 1.011467456817627}
# {'epoch': 8, 'batch': 150, 'loss': 1.020399808883667}
# {'epoch': 9, 'batch': 0, 'loss': 0.8874487280845642}
# {'epoch': 9, 'batch': 30, 'loss': 0.8726872205734253}
# {'epoch': 9, 'batch': 60, 'loss': 0.9120169878005981}
# {'epoch': 9, 'batch': 90, 'loss': 0.9195442199707031}
# {'epoch': 9, 'batch': 120, 'loss': 0.9506904482841492}
# {'epoch': 9, 'batch': 150, 'loss': 0.9495272636413574}
# {'epoch': 10, 'batch': 0, 'loss': 0.802480936050415}
# {'epoch': 10, 'batch': 30, 'loss': 0.8081108331680298}
# {'epoch': 10, 'batch': 60, 'loss': 0.8360040187835693}
# {'epoch': 10, 'batch': 90, 'loss': 0.8355085849761963}
# {'epoch': 10, 'batch': 120, 'loss': 0.8687360286712646}
# {'epoch': 10, 'batch': 150, 'loss': 0.8744609355926514}
# {'epoch': 11, 'batch': 0, 'loss': 0.7393906116485596}
# {'epoch': 11, 'batch': 30, 'loss': 0.7307623028755188}
# {'epoch': 11, 'batch': 60, 'loss': 0.7519776821136475}
# {'epoch': 11, 'batch': 90, 'loss': 0.7652683854103088}
# {'epoch': 11, 'batch': 120, 'loss': 0.7949627637863159}
# {'epoch': 11, 'batch': 150, 'loss': 0.827473521232605}
# {'epoch': 12, 'batch': 0, 'loss': 0.6699042320251465}
# {'epoch': 12, 'batch': 30, 'loss': 0.6611495018005371}
# {'epoch': 12, 'batch': 60, 'loss': 0.6756191849708557}
# {'epoch': 12, 'batch': 90, 'loss': 0.6770946383476257}
# {'epoch': 12, 'batch': 120, 'loss': 0.7093554139137268}
# {'epoch': 12, 'batch': 150, 'loss': 0.7163333296775818}
# {'epoch': 13, 'batch': 0, 'loss': 0.5872390270233154}
# {'epoch': 13, 'batch': 30, 'loss': 0.5737771987915039}
# {'epoch': 13, 'batch': 60, 'loss': 0.6090291738510132}
# {'epoch': 13, 'batch': 90, 'loss': 0.6119735240936279}
# {'epoch': 13, 'batch': 120, 'loss': 0.6249092221260071}
# {'epoch': 13, 'batch': 150, 'loss': 0.654262363910675}
# {'epoch': 14, 'batch': 0, 'loss': 0.5011950731277466}
# {'epoch': 14, 'batch': 30, 'loss': 0.5151339173316956}
# {'epoch': 14, 'batch': 60, 'loss': 0.5266673564910889}
# {'epoch': 14, 'batch': 90, 'loss': 0.5412261486053467}
# {'epoch': 14, 'batch': 120, 'loss': 0.5478402376174927}
# {'epoch': 14, 'batch': 150, 'loss': 0.5786943435668945}
# {'epoch': 15, 'batch': 0, 'loss': 0.4497630000114441}
# {'epoch': 15, 'batch': 30, 'loss': 0.43524038791656494}
# {'epoch': 15, 'batch': 60, 'loss': 0.4495343267917633}
# {'epoch': 15, 'batch': 90, 'loss': 0.4827597737312317}
# {'epoch': 15, 'batch': 120, 'loss': 0.4950449764728546}
# {'epoch': 15, 'batch': 150, 'loss': 0.501184344291687}
# {'epoch': 16, 'batch': 0, 'loss': 0.37414348125457764}
# {'epoch': 16, 'batch': 30, 'loss': 0.3829638659954071}
# {'epoch': 16, 'batch': 60, 'loss': 0.38545462489128113}
# {'epoch': 16, 'batch': 90, 'loss': 0.4126356244087219}
# {'epoch': 16, 'batch': 120, 'loss': 0.42052826285362244}
# {'epoch': 16, 'batch': 150, 'loss': 0.4586293697357178}
# {'epoch': 17, 'batch': 0, 'loss': 0.3205265402793884}
# {'epoch': 17, 'batch': 30, 'loss': 0.3219320774078369}
# {'epoch': 17, 'batch': 60, 'loss': 0.34235507249832153}
# {'epoch': 17, 'batch': 90, 'loss': 0.343624472618103}
# {'epoch': 17, 'batch': 120, 'loss': 0.3699858784675598}
# {'epoch': 17, 'batch': 150, 'loss': 0.39419791102409363}
# {'epoch': 18, 'batch': 0, 'loss': 0.2919274568557739}
# {'epoch': 18, 'batch': 30, 'loss': 0.2857275605201721}
# {'epoch': 18, 'batch': 60, 'loss': 0.3011249899864197}
# {'epoch': 18, 'batch': 90, 'loss': 0.3144456148147583}
# {'epoch': 18, 'batch': 120, 'loss': 0.31650757789611816}
# {'epoch': 18, 'batch': 150, 'loss': 0.3378410339355469}
# {'epoch': 19, 'batch': 0, 'loss': 0.2502492368221283}
# {'epoch': 19, 'batch': 30, 'loss': 0.250143826007843}
# {'epoch': 19, 'batch': 60, 'loss': 0.2548322379589081}
# {'epoch': 19, 'batch': 90, 'loss': 0.27583280205726624}
# {'epoch': 19, 'batch': 120, 'loss': 0.273897260427475}
# {'epoch': 19, 'batch': 150, 'loss': 0.30327460169792175}
# {'epoch': 20, 'batch': 0, 'loss': 0.20184177160263062}
# {'epoch': 20, 'batch': 30, 'loss': 0.2377667874097824}
# {'epoch': 20, 'batch': 60, 'loss': 0.231491819024086}
# {'epoch': 20, 'batch': 90, 'loss': 0.23675909638404846}
# {'epoch': 20, 'batch': 120, 'loss': 0.2553647756576538}
# {'epoch': 20, 'batch': 150, 'loss': 0.2730293571949005}
# {'epoch': 21, 'batch': 0, 'loss': 0.20280280709266663}
# {'epoch': 21, 'batch': 30, 'loss': 0.1990049034357071}
# {'epoch': 21, 'batch': 60, 'loss': 0.22602443397045135}
# {'epoch': 21, 'batch': 90, 'loss': 0.2211788296699524}
# {'epoch': 21, 'batch': 120, 'loss': 0.23912306129932404}
# {'epoch': 21, 'batch': 150, 'loss': 0.25108546018600464}
# {'epoch': 22, 'batch': 0, 'loss': 0.19078637659549713}
# {'epoch': 22, 'batch': 30, 'loss': 0.20480936765670776}
# {'epoch': 22, 'batch': 60, 'loss': 0.1957399547100067}
# {'epoch': 22, 'batch': 90, 'loss': 0.21498864889144897}
# {'epoch': 22, 'batch': 120, 'loss': 0.22141756117343903}
# {'epoch': 22, 'batch': 150, 'loss': 0.22635751962661743}
# {'epoch': 23, 'batch': 0, 'loss': 0.17281313240528107}
# {'epoch': 23, 'batch': 30, 'loss': 0.18410757184028625}
# {'epoch': 23, 'batch': 60, 'loss': 0.18892411887645721}
# {'epoch': 23, 'batch': 90, 'loss': 0.19209058582782745}
# {'epoch': 23, 'batch': 120, 'loss': 0.204175665974617}
# {'epoch': 23, 'batch': 150, 'loss': 0.22059686481952667}
# {'epoch': 24, 'batch': 0, 'loss': 0.16526071727275848}
# {'epoch': 24, 'batch': 30, 'loss': 0.17607496678829193}
# {'epoch': 24, 'batch': 60, 'loss': 0.18761375546455383}
# {'epoch': 24, 'batch': 90, 'loss': 0.19037200510501862}
# {'epoch': 24, 'batch': 120, 'loss': 0.20067228376865387}
# {'epoch': 24, 'batch': 150, 'loss': 0.2122858464717865}
# {'epoch': 25, 'batch': 0, 'loss': 0.17047595977783203}
# {'epoch': 25, 'batch': 30, 'loss': 0.1701158732175827}
# {'epoch': 25, 'batch': 60, 'loss': 0.1766161471605301}
# {'epoch': 25, 'batch': 90, 'loss': 0.186391681432724}
# {'epoch': 25, 'batch': 120, 'loss': 0.2059750109910965}
# {'epoch': 25, 'batch': 150, 'loss': 0.21528804302215576}
# {'epoch': 26, 'batch': 0, 'loss': 0.17236214876174927}
# {'epoch': 26, 'batch': 30, 'loss': 0.1660621613264084}
# {'epoch': 26, 'batch': 60, 'loss': 0.1800508350133896}
# {'epoch': 26, 'batch': 90, 'loss': 0.18821865320205688}
# {'epoch': 26, 'batch': 120, 'loss': 0.19904474914073944}
# {'epoch': 26, 'batch': 150, 'loss': 0.2198728621006012}
# {'epoch': 27, 'batch': 0, 'loss': 0.1698494404554367}
# {'epoch': 27, 'batch': 30, 'loss': 0.1736350953578949}
# {'epoch': 27, 'batch': 60, 'loss': 0.17368152737617493}
# {'epoch': 27, 'batch': 90, 'loss': 0.18370065093040466}
# {'epoch': 27, 'batch': 120, 'loss': 0.2042960673570633}
# {'epoch': 27, 'batch': 150, 'loss': 0.23394228518009186}
# {'epoch': 28, 'batch': 0, 'loss': 0.16926293075084686}
# {'epoch': 28, 'batch': 30, 'loss': 0.18925106525421143}
# {'epoch': 28, 'batch': 60, 'loss': 0.18018415570259094}
# {'epoch': 28, 'batch': 90, 'loss': 0.1944206804037094}
# {'epoch': 28, 'batch': 120, 'loss': 0.20171429216861725}
# {'epoch': 28, 'batch': 150, 'loss': 0.22982019186019897}
# {'epoch': 29, 'batch': 0, 'loss': 0.16284498572349548}
# {'epoch': 29, 'batch': 30, 'loss': 0.18137666583061218}
# {'epoch': 29, 'batch': 60, 'loss': 0.18620982766151428}
# {'epoch': 29, 'batch': 90, 'loss': 0.18670591711997986}
# {'epoch': 29, 'batch': 120, 'loss': 0.21088409423828125}
# {'epoch': 29, 'batch': 150, 'loss': 0.214562326669693}

# %%
# Compare the loss evolution
plt.plot(losses_RNN, label='RNN')
plt.plot(losses_LSTM, label='LSTM')
plt.plot(losses_GRU, label='GRU')
plt.title('Comparison of the losses')
plt.legend()
plt.show()

# %% [markdown]
# As we can see, the LSTM model seems to be the best one. In fact, its accuracy is significantly smaller than the 2 others, especially at the end of the training.

# %% [markdown]
# <span style="color:blue">
#
# **Exercise 4:** Train your best model on a different dataset. Use the 'inaugural' corpus of the [NLTK](https://www.nltk.org/) library. Once trained generate some text with as we did for the model trained on the Shakespeare dataset. Compare the generated texts with both models using the smae "seed" (input) text. What differences do you appreciate? Why are they different?
#
# </span>
#
# The Natural Language Toolkit, or more commonly NLTK, is a suite of datasets, libraries and models for symbolic and statistical natural language processing (NLP). The Inaugural Address Corpus contains the US presidential inaugural addresses from 1789 to 2017. The following code loads the 'inaugural' corpus:

# %%
import nltk
nltk.download('inaugural')

inaugural = nltk.corpus.inaugural
text = inaugural.raw()

print(f'Length of text: {len(text)} characters')
# Out:
# Length of text: 807276 characters
# [nltk_data] Downloading package inaugural to /root/nltk_data...
# [nltk_data]   Package inaugural is already up-to-date!

# %%
class DatasetFromText(Dataset):
    def __init__(self,text, sequence_length):
        self.sequence_length = sequence_length

        # The whole sequence of characters in the text file (including characters like the end of line character '\n', punctuation marks, etc.)
        self.chars = text
        # The list of unique characters (our vocabulary)
        self.uniq_chars = self.get_uniq_chars()

        # A dictionary with indices as keys and characters as values
        self.index_to_char = {index: char for index, char in enumerate(self.uniq_chars)}
        # A dictionary with characters as keys and indices as values
        self.char_to_index = {char: index for index, char in enumerate(self.uniq_chars)}

        # The whole sequence of character indexes
        # We want to vectorize our text using one-hot vectors at character level
        # But instead of using the one-hot vector we just keep the index of the 1 value
        self.chars_indices = [self.char_to_index[w] for w in self.chars]

        # Split the sequence into chunks of `sequence_length` characters
        # `x` is the input to the model and `y` is the output of the model
        # `y` is the same seuqence as `x` but one character shifted to the right.
        self.x, self.y = self.get_data()

    def get_uniq_chars(self):
        char_counts = Counter(self.chars)
        uniq_chars = sorted(char_counts, key=char_counts.get, reverse=True)
        print(f'Unique characters (vocabulary size): {len(uniq_chars)}')
        return uniq_chars

    def get_data(self):
        x,y = [], []
        for index in range(0, len(self.chars_indices)-self.sequence_length, self.sequence_length):
            x.append(np.array(self.chars_indices[index:index+self.sequence_length]))
            y.append(np.array(self.chars_indices[index+1:index+self.sequence_length+1]))

        return  torch.from_numpy(np.array(x)), torch.from_numpy(np.array(y)).long()

    def __len__(self):
        return len(self.y)

    def __getitem__(self, idx):
        assert ((idx >= 0) & (idx < len(self.y))), "Dataset index out of range"
        return self.x[idx], self.y[idx]

# %%
# Create the dataset
sequence_length = 100
NLTKDataset = DatasetFromText(text, sequence_length)

print(f'We have {NLTKDataset.x.shape[0]} input sequence samples of length {NLTKDataset.x.shape[1]} \
and {NLTKDataset.y.shape[0]} label sequences of length {NLTKDataset.y.shape[1]}')

# Create the Torch DataLoader
batch_size = 64
train_loader = DataLoader(NLTKDataset, shuffle=True, batch_size=batch_size, drop_last=True)
# Out:
# Unique characters (vocabulary size): 85
# We have 8072 input sequence samples of length 100 and 8072 label sequences of length 100

# %%
# Train the best model
input_dim = len(NLTKDataset.uniq_chars)
embedding_dim = 300
hidden_dim = 1024
output_dim = len(NLTKDataset.uniq_chars)
n_layers = 2
drop_prob = 0.2
best_model = ModelLSTM(input_dim, embedding_dim, hidden_dim, output_dim, n_layers, drop_prob).to(device)
print(best_model)

losses_NLTK = trainLSTM(train_loader, best_model, batch_size, sequence_length, num_epochs)
# Out:
# ModelLSTM(
#   (embedding): Embedding(85, 300)
#   (lstm): LSTM(300, 1024, num_layers=2, batch_first=True)
#   (fc): Linear(in_features=1024, out_features=85, bias=True)
# )
# {'epoch': 0, 'batch': 0, 'loss': 4.437342643737793}
# {'epoch': 0, 'batch': 30, 'loss': 2.250579595565796}
# {'epoch': 0, 'batch': 60, 'loss': 1.8071426153182983}
# {'epoch': 0, 'batch': 90, 'loss': 1.5494171380996704}
# {'epoch': 0, 'batch': 120, 'loss': 1.463289737701416}
# {'epoch': 1, 'batch': 0, 'loss': 1.4018356800079346}
# {'epoch': 1, 'batch': 30, 'loss': 1.3583672046661377}
# {'epoch': 1, 'batch': 60, 'loss': 1.2713263034820557}
# {'epoch': 1, 'batch': 90, 'loss': 1.282905101776123}
# {'epoch': 1, 'batch': 120, 'loss': 1.1849476099014282}
# {'epoch': 2, 'batch': 0, 'loss': 1.190494418144226}
# {'epoch': 2, 'batch': 30, 'loss': 1.2145084142684937}
# {'epoch': 2, 'batch': 60, 'loss': 1.1603773832321167}
# {'epoch': 2, 'batch': 90, 'loss': 1.1978057622909546}
# {'epoch': 2, 'batch': 120, 'loss': 1.1701600551605225}
# {'epoch': 3, 'batch': 0, 'loss': 1.0510295629501343}
# {'epoch': 3, 'batch': 30, 'loss': 1.0941200256347656}
# {'epoch': 3, 'batch': 60, 'loss': 1.0686328411102295}
# {'epoch': 3, 'batch': 90, 'loss': 1.1089946031570435}
# {'epoch': 3, 'batch': 120, 'loss': 1.0940951108932495}
# {'epoch': 4, 'batch': 0, 'loss': 1.049719214439392}
# {'epoch': 4, 'batch': 30, 'loss': 1.0311784744262695}
# {'epoch': 4, 'batch': 60, 'loss': 1.0484790802001953}
# {'epoch': 4, 'batch': 90, 'loss': 1.0557292699813843}
# {'epoch': 4, 'batch': 120, 'loss': 1.0286855697631836}
# {'epoch': 5, 'batch': 0, 'loss': 0.9978272318840027}
# {'epoch': 5, 'batch': 30, 'loss': 1.0564587116241455}
# {'epoch': 5, 'batch': 60, 'loss': 0.9984630346298218}
# {'epoch': 5, 'batch': 90, 'loss': 1.0733917951583862}
# {'epoch': 5, 'batch': 120, 'loss': 1.035464882850647}
# {'epoch': 6, 'batch': 0, 'loss': 0.9567047357559204}
# {'epoch': 6, 'batch': 30, 'loss': 0.9733031392097473}
# {'epoch': 6, 'batch': 60, 'loss': 0.9663451313972473}
# {'epoch': 6, 'batch': 90, 'loss': 1.0037049055099487}
# {'epoch': 6, 'batch': 120, 'loss': 0.9701718688011169}
# {'epoch': 7, 'batch': 0, 'loss': 0.9250750541687012}
# {'epoch': 7, 'batch': 30, 'loss': 0.9162862300872803}
# {'epoch': 7, 'batch': 60, 'loss': 0.9155490398406982}
# {'epoch': 7, 'batch': 90, 'loss': 0.9561604261398315}
# {'epoch': 7, 'batch': 120, 'loss': 0.9476622939109802}
# {'epoch': 8, 'batch': 0, 'loss': 0.8829111456871033}
# {'epoch': 8, 'batch': 30, 'loss': 0.8865566253662109}
# {'epoch': 8, 'batch': 60, 'loss': 0.9012455940246582}
# {'epoch': 8, 'batch': 90, 'loss': 0.8942367434501648}
# {'epoch': 8, 'batch': 120, 'loss': 0.9256709814071655}
# {'epoch': 9, 'batch': 0, 'loss': 0.838212788105011}
# {'epoch': 9, 'batch': 30, 'loss': 0.829547107219696}
# {'epoch': 9, 'batch': 60, 'loss': 0.8650611639022827}
# {'epoch': 9, 'batch': 90, 'loss': 0.8637645244598389}
# {'epoch': 9, 'batch': 120, 'loss': 0.8485326170921326}
# {'epoch': 10, 'batch': 0, 'loss': 0.803992509841919}
# {'epoch': 10, 'batch': 30, 'loss': 0.8061960339546204}
# {'epoch': 10, 'batch': 60, 'loss': 0.7959095239639282}
# {'epoch': 10, 'batch': 90, 'loss': 0.7987815737724304}
# {'epoch': 10, 'batch': 120, 'loss': 0.8175742626190186}
# {'epoch': 11, 'batch': 0, 'loss': 0.7285338640213013}
# {'epoch': 11, 'batch': 30, 'loss': 0.7317712306976318}
# {'epoch': 11, 'batch': 60, 'loss': 0.7452101111412048}
# {'epoch': 11, 'batch': 90, 'loss': 0.7856088280677795}
# {'epoch': 11, 'batch': 120, 'loss': 0.7943675518035889}
# {'epoch': 12, 'batch': 0, 'loss': 0.6869579553604126}
# {'epoch': 12, 'batch': 30, 'loss': 0.6781759858131409}
# {'epoch': 12, 'batch': 60, 'loss': 0.7006710767745972}
# {'epoch': 12, 'batch': 90, 'loss': 0.7229342460632324}
# {'epoch': 12, 'batch': 120, 'loss': 0.7252213358879089}
# {'epoch': 13, 'batch': 0, 'loss': 0.6201964020729065}
# {'epoch': 13, 'batch': 30, 'loss': 0.6264315247535706}
# {'epoch': 13, 'batch': 60, 'loss': 0.6638101935386658}
# {'epoch': 13, 'batch': 90, 'loss': 0.6770825982093811}
# {'epoch': 13, 'batch': 120, 'loss': 0.7100750207901001}
# {'epoch': 14, 'batch': 0, 'loss': 0.5886146426200867}
# {'epoch': 14, 'batch': 30, 'loss': 0.5637287497520447}
# {'epoch': 14, 'batch': 60, 'loss': 0.5847483277320862}
# {'epoch': 14, 'batch': 90, 'loss': 0.6233553886413574}
# {'epoch': 14, 'batch': 120, 'loss': 0.6427653431892395}
# {'epoch': 15, 'batch': 0, 'loss': 0.520028293132782}
# {'epoch': 15, 'batch': 30, 'loss': 0.5039743185043335}
# {'epoch': 15, 'batch': 60, 'loss': 0.5430872440338135}
# {'epoch': 15, 'batch': 90, 'loss': 0.5554189682006836}
# {'epoch': 15, 'batch': 120, 'loss': 0.5775521397590637}
# {'epoch': 16, 'batch': 0, 'loss': 0.4465480446815491}
# {'epoch': 16, 'batch': 30, 'loss': 0.45221176743507385}
# {'epoch': 16, 'batch': 60, 'loss': 0.4922526180744171}
# {'epoch': 16, 'batch': 90, 'loss': 0.506037175655365}
# {'epoch': 16, 'batch': 120, 'loss': 0.5230965614318848}
# {'epoch': 17, 'batch': 0, 'loss': 0.4161289632320404}
# {'epoch': 17, 'batch': 30, 'loss': 0.4268820583820343}
# {'epoch': 17, 'batch': 60, 'loss': 0.44903525710105896}
# {'epoch': 17, 'batch': 90, 'loss': 0.450226366519928}
# {'epoch': 17, 'batch': 120, 'loss': 0.48178771138191223}
# {'epoch': 18, 'batch': 0, 'loss': 0.3621608018875122}
# {'epoch': 18, 'batch': 30, 'loss': 0.36428967118263245}
# {'epoch': 18, 'batch': 60, 'loss': 0.39803561568260193}
# {'epoch': 18, 'batch': 90, 'loss': 0.41089415550231934}
# {'epoch': 18, 'batch': 120, 'loss': 0.44197922945022583}
# {'epoch': 19, 'batch': 0, 'loss': 0.34154078364372253}
# {'epoch': 19, 'batch': 30, 'loss': 0.31484073400497437}
# {'epoch': 19, 'batch': 60, 'loss': 0.3373135030269623}
# {'epoch': 19, 'batch': 90, 'loss': 0.3732728660106659}
# {'epoch': 19, 'batch': 120, 'loss': 0.39114534854888916}
# {'epoch': 20, 'batch': 0, 'loss': 0.2934424579143524}
# {'epoch': 20, 'batch': 30, 'loss': 0.2772256135940552}
# {'epoch': 20, 'batch': 60, 'loss': 0.29830512404441833}
# {'epoch': 20, 'batch': 90, 'loss': 0.31706827878952026}
# {'epoch': 20, 'batch': 120, 'loss': 0.336986243724823}
# {'epoch': 21, 'batch': 0, 'loss': 0.2402137964963913}
# {'epoch': 21, 'batch': 30, 'loss': 0.25402548909187317}
# {'epoch': 21, 'batch': 60, 'loss': 0.26598310470581055}
# {'epoch': 21, 'batch': 90, 'loss': 0.28054481744766235}
# {'epoch': 21, 'batch': 120, 'loss': 0.31419607996940613}
# {'epoch': 22, 'batch': 0, 'loss': 0.2146933674812317}
# {'epoch': 22, 'batch': 30, 'loss': 0.2273886501789093}
# {'epoch': 22, 'batch': 60, 'loss': 0.22824206948280334}
# {'epoch': 22, 'batch': 90, 'loss': 0.2646402418613434}
# {'epoch': 22, 'batch': 120, 'loss': 0.2797256410121918}
# {'epoch': 23, 'batch': 0, 'loss': 0.19075524806976318}
# {'epoch': 23, 'batch': 30, 'loss': 0.1975821852684021}
# {'epoch': 23, 'batch': 60, 'loss': 0.20134733617305756}
# {'epoch': 23, 'batch': 90, 'loss': 0.2193727046251297}
# {'epoch': 23, 'batch': 120, 'loss': 0.2385493814945221}
# {'epoch': 24, 'batch': 0, 'loss': 0.16696897149085999}
# {'epoch': 24, 'batch': 30, 'loss': 0.1795557141304016}
# {'epoch': 24, 'batch': 60, 'loss': 0.1778586357831955}
# {'epoch': 24, 'batch': 90, 'loss': 0.2028675526380539}
# {'epoch': 24, 'batch': 120, 'loss': 0.21823203563690186}
# {'epoch': 25, 'batch': 0, 'loss': 0.15617607533931732}
# {'epoch': 25, 'batch': 30, 'loss': 0.15907731652259827}
# {'epoch': 25, 'batch': 60, 'loss': 0.17256247997283936}
# {'epoch': 25, 'batch': 90, 'loss': 0.1790810525417328}
# {'epoch': 25, 'batch': 120, 'loss': 0.18708090484142303}
# {'epoch': 26, 'batch': 0, 'loss': 0.13280144333839417}
# {'epoch': 26, 'batch': 30, 'loss': 0.153543621301651}
# {'epoch': 26, 'batch': 60, 'loss': 0.15346769988536835}
# {'epoch': 26, 'batch': 90, 'loss': 0.1670282483100891}
# {'epoch': 26, 'batch': 120, 'loss': 0.178623765707016}
# {'epoch': 27, 'batch': 0, 'loss': 0.13046951591968536}
# {'epoch': 27, 'batch': 30, 'loss': 0.13980025053024292}
# {'epoch': 27, 'batch': 60, 'loss': 0.14775095880031586}
# {'epoch': 27, 'batch': 90, 'loss': 0.1587582230567932}
# {'epoch': 27, 'batch': 120, 'loss': 0.17132125794887543}
# {'epoch': 28, 'batch': 0, 'loss': 0.12511850893497467}
# {'epoch': 28, 'batch': 30, 'loss': 0.13030311465263367}
# {'epoch': 28, 'batch': 60, 'loss': 0.1444278061389923}
# {'epoch': 28, 'batch': 90, 'loss': 0.15171687304973602}
# {'epoch': 28, 'batch': 120, 'loss': 0.16583015024662018}
# {'epoch': 29, 'batch': 0, 'loss': 0.12441165745258331}
# {'epoch': 29, 'batch': 30, 'loss': 0.12844710052013397}
# {'epoch': 29, 'batch': 60, 'loss': 0.13510259985923767}
# {'epoch': 29, 'batch': 90, 'loss': 0.1500704437494278}
# {'epoch': 29, 'batch': 120, 'loss': 0.16560770571231842}

# %%
# Loss evolution
plt.plot(losses_NLTK)
plt.title('Train on inaugural corpus')
plt.legend()
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
def predict(dataset, model, text, next_chars=1000):
    model.eval()

    chars = [char for char in text]
    state, cell = model.init_hidden(1)
    state = state.to(device)
    cell = cell.to(device)

    # we start by feeding all the input characters to our model
    x = torch.tensor([dataset.char_to_index[char] for char in chars])
    x = x.unsqueeze(0) # create a batch of 1
    x = x.to(device)

    for i in range(0, next_chars):
        y_pred, (state, cell) = model(x, (state, cell))

        last_char_logits = y_pred[0][-1]
        p = torch.nn.functional.softmax(last_char_logits, dim=0).detach().cpu().numpy()
        char_index = np.random.choice(len(last_char_logits), p=p)
        chars.append(dataset.index_to_char[char_index])

        # the output of the model (a single character index) becomes the input at next iteration
        x = torch.tensor([[char_index]])
        x = x.to(device)

    return chars

# Predictions on Sakespeare dataset
predicted = predict(ShakespeareDataset, modelLSTM,'ROMEO:')
print(''.join(predicted))
# Out:
# ROMEO:
# Indeed, it does say this is the right, and he,
# A madman's mouth is but a paper
# And rapt in secret studies. Thy false use have
# I prized in reverence, though he were my wife's honest.
#
# ELANT:
# Bring forth that fatal screech-owl to begin his woe:
# A pardon as a young man, I'll first,
# And that the queen is valuarous days:
# But now mischance hath trod my title down,
# And that my name forswear thou wilt be married!
# My loving lord, I take my leave off ye:
# I will revenge his wrong to Lady Bona,
# And quit it in the treachery or the thrower-oppreser;
# And suffer'd me, the unity that may
# Be his concealing able to sleep.
#
# ANTIGONUS:
# Call you my heart?
#
# Third Servingman:
# Nay, I knew by his face to the will:
# He, would you note deny, or I will not cast thou,
# Where you were tied in duty, for I cannot counter.
# And you were there, they shall not be full-gorged.
# My husband is thy lord, this is a sisterhor,
# To be your comforter when he is end.
#
# MONTAGUE:
# When I am already, I will take it up for
# pity: yet I'll

# %%
# Predictions on NLTK dataset
predicted = predict(NLTKDataset, best_model,'ROMEO:')
print(''.join(predicted))
# Out:
# ROMEO:
#
# I shall now proceed to take the oath prescribed by the Constitution has declared through the destiny of my American botth. Our recommendation rests being the rewards of partisan services are fear to be attained in accordance with our institutions and essential to the public business caused at large humanity equally across the hills and plains of the obligations of the United States to support armies and new duties which would result to different States and sections from its dissons -- but we must simply do our best efforts to prozour small, will define our American destiny. And your courage and goodness and love will forgotten no longer departure from that no permanent man must again be remembered as an admonition. The one we are now briefly never before us, who spend it was not waging war, and fighting under the authority of the brotherhood of man, the highest law of all our best remedial lines, but such an appointment. The issues of the office which has been arrested by the same ye

# %% [markdown]
# As we can see, in the first case, the result with the first dataset is in the shape of a theater writting, with characters, denoted in capital letters, while the second dataset leads to a complete text (without the previous shape). We can also note that this second dataset leads to long sentences, which are similar to law descriptions for example (juridic words, with long sentences).
#
# But what we can see is that in both cases, the sentences does not really have any sense. Each sentence can make a bit of sense, but there isn't any really logical link between following sentences.
